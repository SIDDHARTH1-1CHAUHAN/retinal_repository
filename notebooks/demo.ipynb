# %% [markdown]
# # Stage 2 Demo
#
# This notebook shows the expected training and inference entrypoints for the Stage 2 retinal disease pipeline.

# %%
from src.inference.predict_pipeline import RetinalDiseasePredictor, format_prediction_for_report

# %%
# predictor = RetinalDiseasePredictor.from_config('configs/model_stage2.yaml')
# prediction = predictor.predict(image_tensor=preprocessed_image, stage1_output={'disease': 'dr', 'confidence': 0.92})
# print(format_prediction_for_report(prediction))
